# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewrudnell/Lecture-Matter_-Cloud-Computing-with-R-and-Colabs/blob/main/Experiment_Design_Lecture_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experimental Design Lecture**
# ## Code: CS001SC001ED001M2
# ## Topic: R statistical computation, Study Case: GGE Biplot
# ### Author: Andrew Yoel Siallagan
# ### date: 13/07/2023

# %% [markdown]
# # **Abstract**
#
# ---
#
# In this lesson, we will discuss how to use the R programming language to help us do data analysis, especially for analysis GGE Interaction in the context of quantitative genetics. In this section, we still use cloud computing methods using Google Colab as a code editor/notebook to write all the script code that we will execute to extracted the insight/information from our data.

# %% [markdown]
# # **Reference**
#
# ---
#
#
# Video:
# >
# * https://youtu.be/0snrD5tQAOA
#
# Books & Journal:
# >
# *   https://doi.org/10.1515/opag-2021-0219
# *   https://vsni.co.uk/blogs/BLUPS_BLUES_breeding_values
# *   https://www.taylorfrancis.com/books/mono/10.1201/9781420040371/gge-biplot-analysis-weikai-yan-manjit-kang

# %%
#Install packages for GGE Biplots
install.packages("GGEBiplots")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘tweenr’, ‘polyclip’, ‘RcppEigen’, ‘ggforce’

# %%
# Call a library for data viz, dataset, & GGEBiplots
library(ggplot2)
library(GGEBiplots)
library(data)

# %%
# Use data Ontario as dataset sample
data (Ontario)

# %%
# look a top 5 rows of data
head(Ontario)
# Out:
#     BH93  EA93  HW93  ID93  KE93  NN93  OA93  RN93  WP93
# ann 4.460 4.150 2.849 3.084 5.940 4.450 4.351 4.039 2.672
# ari 4.417 4.771 2.912 3.506 5.699 5.152 4.956 4.386 2.938
# aug 4.669 4.578 3.098 3.460 6.070 5.025 4.730 3.900 2.621
# cas 4.732 4.745 3.375 3.904 6.224 5.340 4.226 4.893 3.451
# del 4.390 4.603 3.511 3.848 5.773 5.421 5.147 4.098 2.832
# dia 5.178 4.475 2.990 3.774 6.583 5.045 3.985 4.271 2.776

# %%
# Install library DataExplorer for Exploratory Data Analysis (EDA)
install.packages("DataExplorer")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Call Library DataExplorer for Exploratory Data Analysis (EDA)
library("DataExplorer")

# %%
# use function DataExplorer for Exploratory Data Analysis (EDA)
DataExplorer::create_report(Ontario)
# Out:
# processing file: report.rmd
# 1/42
# 2/42 [global_options]
# 3/42
# 4/42 [introduce]
# 5/42
# 6/42 [plot_intro]
# 7/42
# 8/42 [data_structure]
# 9/42
# 10/42 [missing_profile]
# 11/42
# 12/42 [univariate_distribution_header]
# 13/42
# 14/42 [plot_histogram]
# 15/42
# 16/42 [plot_density]
# 17/42
# 18/42 [plot_frequency_bar]
# 19/42
# 20/42 [plot_response_bar]
# 21/42
# 22/42 [plot_with_bar]
# 23/42
# 24/42 [plot_normal_qq]
# 25/42
# 26/42 [plot_response_qq]
# 27/42
# 28/42 [plot_by_qq]
# 29/42
# 30/42 [correlation_analysis]
# 31/42
# 32/42 [principal_component_analysis]
# 33/42
# 34/42 [bivariate_distribution_header]
# 35/42
# 36/42 [plot_response_boxplot]
# 37/42
# 38/42 [plot_by_boxplot]
# 39/42
# 40/42 [plot_response_scatterplot]
# 41/42
# 42/42 [plot_by_scatterplot]
# output file: /content/report.knit.md
# ...

# %%
## Doing analysis of GGE ( Comparison, RankGen, RankEnv, Disc vs Rep, WhichWonWhere)
GGE1<-GGEModel(Ontario)
CompareGens(GGE1,"cas","luc")
# Out:
# plot without title

# %%
DiscRep(GGE1)
# Out:
# plot without title

# %%
EnvRelationship(GGE1)
# Out:
# Warning message:
# “Duplicated aesthetics after name standardisation: hjust and vjust”
# plot without title

# %%
ExamineEnv(GGE1,"WP93")
# Out:
# plot without title

# %%
ExamineGen(GGE1,"cas")
# Out:
# plot without title

# %%
GGEPlot(GGE1)
# Out:
# plot without title

# %%
MeanStability(GGE1)
# Out:
# plot without title

# %%
RankEnv(GGE1)
# Out:
# plot without title

# %%
RankGen(GGE1)
# Out:
# plot without title

# %%
simdata<-data.frame(expand.grid(Genotype=1:10,Environment=1:10,Rep=1:3),Outcome=rnorm(300))
    meantab<-stattable(simdata$Genotype,simdata$Environment,simdata$Outcome,FUN=mean,na.rm=TRUE)
    GGEPlot(GGEModel(meantab))
# Out:
# plot without title

# %%
WhichWon(GGE1)
# Out:
# Warning message:
# “Duplicated aesthetics after name standardisation: hjust and vjust”
# plot without title
